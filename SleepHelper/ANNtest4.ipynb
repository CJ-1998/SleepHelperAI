# %%
from google.colab import drive
drive.mount("/gdrive", force_remount=True)
# Out:
# Mounted at /gdrive

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import LabelEncoder

# data = pd.read_csv("/gdrive/MyDrive/Colab/SleepHelper/noRateData.csv")
data = pd.read_csv("/gdrive/MyDrive/Colab/SleepHelper/noRateData1.csv")
data.columns
data.count()

data = (data - np.min(data)) / (np.max(data) - np.min(data)).values

dataset = data.values
x = dataset[:,0:12]
y = dataset[:,12]

# x = (x - np.min(x)) / (np.max(x) - np.min(x)).values

# y=tf.keras.utils.to_categorical(y)

number_of_train = int(len(dataset)*0.8)

train_x = x[:number_of_train]
train_y = y[:number_of_train]
test_x = x[number_of_train:]
test_y = y[number_of_train:]

train_y=tf.keras.utils.to_categorical(train_y)
test_y=tf.keras.utils.to_categorical(test_y)

# %%
# 모델의 설정
model = Sequential()
model.add(Dense(30,  input_dim=12, activation='relu'))
# model.add(Dense(15, activation='relu'))
# model.add(Dense(6, activation='relu'))
model.add(Dense(2, activation='sigmoid'))

# 모델 컴파일
model.compile(loss='categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy'])

# 모델 실행
model.fit(train_x, train_y, epochs=10, batch_size=10)

# 결과 출력
print("\n Accuracy: %.4f" % (model.evaluate(test_x, test_y)[1]))
# Out:
# Epoch 1/10
# 218/218 [==============================] - 1s 2ms/step - loss: 0.2024 - accuracy: 0.9871
# Epoch 2/10
# 218/218 [==============================] - 0s 2ms/step - loss: 0.0739 - accuracy: 0.9876
# Epoch 3/10
# 218/218 [==============================] - 0s 2ms/step - loss: 0.0709 - accuracy: 0.9876
# Epoch 4/10
# 218/218 [==============================] - 0s 2ms/step - loss: 0.0687 - accuracy: 0.9876
# Epoch 5/10
# 218/218 [==============================] - 0s 2ms/step - loss: 0.0663 - accuracy: 0.9876
# Epoch 6/10
# 218/218 [==============================] - 0s 2ms/step - loss: 0.0642 - accuracy: 0.9876
# Epoch 7/10
# 218/218 [==============================] - 0s 2ms/step - loss: 0.0626 - accuracy: 0.9876
# Epoch 8/10
# 218/218 [==============================] - 0s 2ms/step - loss: 0.0608 - accuracy: 0.9876
# Epoch 9/10
# 218/218 [==============================] - 0s 2ms/step - loss: 0.0594 - accuracy: 0.9876
# Epoch 10/10
# 218/218 [==============================] - 0s 2ms/step - loss: 0.0582 - accuracy: 0.9876
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0699 - accuracy: 0.9853
#
#  Accuracy: 0.9853
