# %%
from google.colab import drive
drive.mount("/gdrive", force_remount=True)
# Out:
# Mounted at /gdrive

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import sys

from keras.models import Sequential, load_model
from keras.layers import Dense
from sklearn.preprocessing import LabelEncoder

# data = pd.read_csv("/gdrive/MyDrive/Colab/SleepHelper/noWakeData1.csv")
data = pd.read_csv("/gdrive/MyDrive/Colab/SleepHelper/noWakeData.csv")
data.columns
# print(data.count())

# data = (data - np.min(data)) / (np.max(data) - np.min(data)).values

dataset = data.values
x = dataset[:,0:11]
y = dataset[:,11]
print(x[0])

# y=tf.keras.utils.to_categorical(y)
# Out:
# [390.         270.          69.23076923  60.          30.
#    0.           0.           0.           0.           0.
#    2.        ]

# %%
model=load_model('/gdrive/MyDrive/Colab/SleepHelper/SleepHelper1.h5')
x=np.array(x)
answer=model.predict(x)

# print(answer)

arr=[]
for j in range(2716):
  max=answer[j][0]
  cnt=0
  for i in range(6):
    if(max<answer[j][i]):
      max=answer[j][i]
      cnt=i
  arr.append(cnt)
    # print(cnt)

print(arr)
print(len(arr))
print((arr==y).tolist())

t=0
f=0
for i in range(2716):
  if(arr[i]==y[i]):
    t=t+1
  else:
    f=f+1

print(t, f)
# Out:
# 85/85 [==============================] - 0s 1ms/step
# ...

# %%
model=load_model('/gdrive/MyDrive/Colab/SleepHelper/SleepHelper1.h5')

train_x=[]

# train_x.append([455,240,(455/240)*100,60,35,60,0,0,0,0,2])
# train_x.append([510,420,(510/420)*100,30,30,30,0,1,0,0,5])
# train_x.append([800,420,(800/420)*100,90,120,30,1,1,1,1,2])
# train_x.append([510,210,(210/510)*100,30,180,30,0,1,0,0,3])
# train_x.append([510,210,41.17647,30,180,30,0,1,0,0,3])
# train_x.append([545,305,(305/545)*100,60,120,60,0,1,0,0,3])
# train_x.append([390,270,(270/390)*100,60,30,0,0,0,0,0,2])
# train_x.append([480,180,(180/480)*100,60,120,60,0,1,0,0,3])
# train_x.append([780,165,(165/780)*100,30,405,0,0,0,2,0,5])
# train_x.append([510,360,(360/510)*100,60,60,30,0,1,0,0,5])
train_x.append([510,360,(360/510)*100,60,60,30,0,1,0,0,5])


print(train_x)
train_x=np.array(train_x)

print(train_x)

ans=model.predict(train_x)
print(ans)

# ans=model.predict(x[0])

max=ans[0][0]
cnt=0

cnt=ans.argmax()
# for i in range(6):
#   if(max<ans[0][i]):
#     max=ans[0][i]
#     cnt=i
# for i in range(6):
#   print("%.4f"%(ans[0][i]))
print(cnt)
# Out:
# [[510, 360, 70.58823529411765, 60, 60, 30, 0, 1, 0, 0, 5]]
# [[510.         360.          70.58823529  60.          60.
#    30.           0.           1.           0.           0.
#     5.        ]]
# 1/1 [==============================] - 0s 52ms/step
# [[1.2608021e-29 1.3634701e-07 1.3699188e-04 3.5632912e-02 1.3347149e-01
#   8.3075839e-01]]
# 5

# %%
def test(k,h):
  train_x=[]
  train_x.append([k+100,k,(k/(k+100))*100,60,60,30,0,0,0,0,h])
  train_x=np.array(train_x)
  ans=model.predict(train_x)
  if(count(ans)==1):
    return k

def count(ans):
  cnt=0
  cnt=ans.argmax()
  # print(cnt)
  if(cnt==5):
    return 1
  else:
    return 0

model=load_model('/gdrive/MyDrive/Colab/SleepHelper/SleepHelper1.h5')


Arr=[]
for h in range(1,6):
  arr=[]
  for k in range(200, 800):
    # print("!!!!!!!!!!")
    # test(k)
      t=test(k,h)
      if(t!=None):
        arr.append(t)
        # print(test(k))
  Arr.append(arr)

print(Arr)
# Out:
# ...
# 1/1 [==============================] - 0s 16ms/step
# ...
# ...
# 1/1 [==============================] - 0s 22ms/step
# ...
