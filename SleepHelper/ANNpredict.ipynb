# %%
from google.colab import drive
drive.mount("/gdrive", force_remount=True)
# Out:
# Mounted at /gdrive

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import sys

from keras.models import Sequential, load_model
from keras.layers import Dense
from sklearn.preprocessing import LabelEncoder

# data = pd.read_csv("/gdrive/MyDrive/Colab/SleepHelper/noWakeData1.csv")
data = pd.read_csv("/gdrive/MyDrive/Colab/SleepHelper/noWakeData.csv")
data.columns
data.count()

data = (data - np.min(data)) / (np.max(data) - np.min(data)).values

dataset = data.values
x = dataset[:,0:11]
y = dataset[:,11]

y=tf.keras.utils.to_categorical(y)

# %%
# train_x=[]
# train_y=[]
# for i in range(1, 1440):
#   temp=[i+10,i,(i+10/i)*100]
#   train_x.append(temp)
#   train_y.append(5)

# train_x=np.array(train_x)

# train_x = (train_x  - train_x.min(axis=0)) / (train_x.max(axis=0) - train_x.min(axis=0))

# train_x=train_x.tolist()

# for x in train_x:
#   x.append(30)
#   x.append(30)
#   x.append(10)
#   x.append(0)
#   x.append(0)
#   x.append(0)
#   x.append(0)
#   x.append(5)

# # print(train_x)

# train_x=np.array(train_x)

# %%
model=load_model('/gdrive/MyDrive/Colab/SleepHelper/SleepHelper.h5')

train_x=[]

# train_x.append([455,240,(455/240)*100,60,35,60,0,0,0,0,2])

# for i in range(1,1440):
#   train_x.append([i+120,i,(i+120/i)*100,60,35,60,2,2,2,2,1])
#   # print(train_x)
#   train_x=np.array(train_x)
#   ans=model.predict(train_x)
#   train_x=train_x.tolist()
#   # train_x=[]
#   # print(ans)
#   if(ans[0][1]==1.0):
#     print(i)
#   else:
#     train_x=[]
    

train_x.append([510,420,(510/420)*100,30,30,30,0,1,0,0,5])
# train_x.append([800,420,(800/420)*100,90,120,30,1,1,1,1,2])

train_x=np.array(train_x)

ans=model.predict(train_x)

print(ans)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-175-d981adc50e65> in <module>
#      24 train_x=np.array(train_x)
#      25
# ---> 26 ans=model.predict(train_x)
#      27
#      28 print(ans)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2031           for step in data_handler.steps():
#    2032             callbacks.on_predict_batch_begin(step)
# ...
