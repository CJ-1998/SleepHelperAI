# %%
from google.colab import drive
drive.mount("/gdrive", force_remount=True)
# Out:
# Mounted at /gdrive

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import LabelEncoder

# data = pd.read_csv("/gdrive/MyDrive/Colab/SleepHelper/noWakeData1.csv")
data = pd.read_csv("/gdrive/MyDrive/Colab/SleepHelper/noWakeData.csv")
data.columns
data.count()

data = (data - np.min(data)) / (np.max(data) - np.min(data)).values

dataset = data.values
x = dataset[:,0:11]
y = dataset[:,11]

# y=tf.keras.utils.to_categorical(y)

number_of_train = int(len(dataset)*0.8)

train_x = x[:number_of_train]
train_y = y[:number_of_train]
test_x = x[number_of_train:]
test_y = y[number_of_train:]

train_y=tf.keras.utils.to_categorical(train_y)
test_y=tf.keras.utils.to_categorical(test_y)

# print(test_y)

# %%
# 모델의 설정
model = Sequential()
model.add(Dense(30,  input_dim=11, activation='relu'))
# model.add(Dense(30, activation='relu'))
# model.add(Dense(15, activation='relu'))
model.add(Dense(2, activation='sigmoid'))

# 모델 컴파일
model.compile(loss='categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy'])

# 모델 실행
model.fit(train_x, train_y, epochs=10, batch_size=10)

# 결과 출력
print("\n Accuracy: %.4f" % (model.evaluate(test_x, test_y)[1]))
# Out:
# Epoch 1/10
# 218/218 [==============================] - 1s 2ms/step - loss: 0.1647 - accuracy: 0.9880
# Epoch 2/10
# 218/218 [==============================] - 0s 2ms/step - loss: 0.0798 - accuracy: 0.9880
# Epoch 3/10
# 218/218 [==============================] - 0s 2ms/step - loss: 0.0746 - accuracy: 0.9880
# Epoch 4/10
# 218/218 [==============================] - 0s 2ms/step - loss: 0.0700 - accuracy: 0.9880
# Epoch 5/10
# 218/218 [==============================] - 0s 2ms/step - loss: 0.0662 - accuracy: 0.9880
# Epoch 6/10
# 218/218 [==============================] - 0s 2ms/step - loss: 0.0623 - accuracy: 0.9880
# Epoch 7/10
# 218/218 [==============================] - 0s 2ms/step - loss: 0.0586 - accuracy: 0.9880
# Epoch 8/10
# 218/218 [==============================] - 0s 2ms/step - loss: 0.0553 - accuracy: 0.9880
# Epoch 9/10
# 218/218 [==============================] - 0s 2ms/step - loss: 0.0527 - accuracy: 0.9880
# Epoch 10/10
# 218/218 [==============================] - 0s 2ms/step - loss: 0.0500 - accuracy: 0.9880
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0459 - accuracy: 0.9890
#
#  Accuracy: 0.9890
